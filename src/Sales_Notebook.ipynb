# %%
from pyspark.sql import functions as  F
data = [
    (1, "Laptop", 50000),
    (2, "Phone",  30000),
    (3, "Tablet", 20000),
    (4,"Laptop", 60000),
    (5, "Mobile",  40000),
    (6,"Laptop", 56000)
]
columns = ["id" , "product", "price"]
df = spark.createDataFrame(data, columns)
result = df.withColumn("Tax", F.col("price") * .18)
display(result)
