# %%
dbutils.widgets.text("country", "India")
dbutils.widgets.text("min_sales", "20000")

# %%
#Read the parameters

country = dbutils.widgets.get("country")
min_sales = dbutils.widgets.get("min_sales")
print("Country",country)
print("Min Sales",min_sales)

# %%
data = [
    (1, "Laptop", "India", 20000),
    (2, "Phone", "USA", 10000),
    (3, "Tablet", "India", 15000),
    (4, "Laptop", "Canada", 30000 ),  
    (5, "Phone", "India", 12000),
    (6, "Tablet", "USA", 18000),
    (7, "Laptop", "Canada", 25000),
    (8, "Phone", "Canada", 16000),
    (9, "Watch", "India", 14000),
    (10, "Watch", "USA", 19000)
]

columns = ["id", "product", "country", "sales"] 
df = spark.createDataFrame(data, columns)
display(df)
